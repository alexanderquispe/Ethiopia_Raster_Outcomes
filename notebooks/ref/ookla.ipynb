# %%
import geopandas as gpd

# %%
ookla = gpd.read_file("../../Data/Shapefiles/9_internet_speed/2020-04-01_performance_fixed_tiles.zip")
# time= ""

# %%
eth = gpd.read_file('../../Data/gjson/adm_0.geojson')

# %%
eth_internet = gpd.sjoin(ookla, eth, op="within")
# Out:
# c:\Users\Jhon\.virtualenvs\etiopia_outcomes-_zp3n1XV\lib\site-packages\IPython\core\interactiveshell.py:3517: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
eth_internet.to_file(
    "../../Data/gjson/okkla/ookla_intenet.geojson", driver="GeoJSON"
)

# %%
eth_internet.plot()
# Out:
# <Axes: >

# %%
eth.plot()
# Out:
# <Axes: >
